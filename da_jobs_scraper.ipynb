# %% [markdown]
# # Web Scraping Data Analyst Jobs from Indeed

# %% [markdown]
# #### In this project, I utilize [Selenium](https://www.selenium.dev), [BeautifulSoup4](https://pypi.org/project/beautifulsoup4/) and [Pandas](https://pandas.pydata.org/) to scrape data about Data Analyst jobs in Alberta, Canada, from [Indeed](https://www.ca.indeed.com).

# %% [markdown]
# This project uses the following Python modules:
# - pandas
# - selenium
# - webdriver-manager
# - nltk
# - BeautifulSoup4
#
# ### Overview
# ___
#
# To scrape the data, we'll use Selenium to enter "Data Analyst" in the main search bar and "Alberta" in the location search bar. We'll then iteratively open the jobs from the search results in a new tab using Selenium again and extract the desired details from the page source using BeautifulSoup into a Pandas DataFrame. Once we're done with a page of the search results and if the results span multiple pages, we'll utilize Selenium to click on the ">" (i.e. "Next Page") button and extract the desired details from each job on the new page.
#
# Finally, we'll store the collected data in a csv file.
#
# As a bonus, we'll use the nltk module to tokenize the summaries of each scraped job and count the number of times a word appears overall in an attempt to find the skills and attributes most commonly required of applicants for Data Analyst jobs posted on Indeed.
#
# Also, note that it is possible to use the Requests Python module instead of Selenium for this project. I just preferred to use Selenium.

# %% [markdown]
# #### Step 1: Import the necessary modules for the webscraping

# %%
import re, csv
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# #### Step 2: Define a function for getting the "next page" button in the job search results page.

# %%
def find_next(soup, driver):
    # Get next page link
    pages_ul = soup.find("ul", attrs={"class": "pagination-list"})
    nextpage_anchor = pages_ul.find_all("li")[-1].contents[0]
    
    if nextpage_anchor.get("aria-label") == "Next":
        nextpage = driver.find_element(By.XPATH, f"//a[@href=\'{nextpage_anchor.get('href')}\']")
    else:
        nextpage = None
    
    return nextpage

# %% [markdown]
# #### Step 4: Initialize the Chrome Webdriver

# %%
# Initialize web driver
options = webdriver.ChromeOptions()
options.add_argument("headless")
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)

# %% [markdown]
# #### Step 5: Search for Data Analyst jobs in Alberta using Selenium

# %%
query = "Data Analyst"
location = "Alberta"
indeed_url = "https://ca.indeed.com/"

# Get Indeed homepage
driver.get(indeed_url)

# Find input elements
query_input = driver.find_element(By.NAME, "q")
location_input = driver.find_element(By.NAME, "l")

# Enter job query and location
query_input.send_keys(Keys.CONTROL + "a")
query_input.send_keys(Keys.DELETE)
query_input.send_keys(query)

location_input.send_keys(Keys.CONTROL + "a")
location_input.send_keys(Keys.DELETE)
location_input.send_keys(location)

# "Press 'ENTER'" to search DA jobs
location_input.send_keys(Keys.RETURN)

# %% [markdown]
# #### Step 6: Iterate over jobs in search results and extract data into a DataFrame

# %%
# Write column headers to file
column_headers = ["Job_Title", "Job_Type", "Company", "Location", "Remote", "Salary", "Summary"]
df = pd.DataFrame(columns=column_headers)

# Iterate over all result pages
while True:
    # Get jobs list and job links
    joblist_page = driver.page_source

    soup = BeautifulSoup(joblist_page, "html.parser")

    # Get job list html
    joblist = soup.find("ul", attrs={"class": "jobsearch-ResultsList"})
    
    # Iterate over jobs in the job list and scrape relevant data from the current page
    for job in joblist.find_all("div", attrs={"class": "cardOutline"}):
        job_title_anchor = job.find("a", attrs={"class": "jcs-JobTitle"})

        title = job_title_anchor.get_text()
        company = job.find("span", attrs={"class": "companyName"}).get_text()
        location = job.find("div", attrs={"class": "companyLocation"}).get_text()

        remote = None
        if "remote" in location.lower():
            remote = True
            location = re.sub("Remote in ", "", location, flags=re.I)
        else:
            remote = False

        location = re.sub("\+\d+\s*location", "", location, flags=re.I)

        job_url = indeed_url + job_title_anchor.get("href")[1:]   # the slicing is for removing the leading '/'

        # Open job details page in new tab
        driver.execute_script("window.open('');")
        driver.switch_to.window(driver.window_handles[1])
        driver.get(job_url)

        job_view = driver.find_element(By.ID, "viewJobSSRRoot")
        job_view_soup = BeautifulSoup(job_view.get_attribute("outerHTML"), "html.parser")

        job_details = job_view_soup.find_all("div", attrs={"class": "jobsearch-JobDescriptionSection-sectionItem"})

        # Obtain the job salary and job type ('full time', 'temporary', etc...)
        # if these details are available
        salary = None
        job_type = None
        for detail in job_details:

            # Parse salary text. Some job postings show
            # a salary range in hour, month or year
            # In this project, we'll take the mean of the salary range
            # and convert every salary to the monthly value for storage
            if detail.contents[0].get_text() == "Salary":
                salary_text = detail.contents[1].get_text().replace(",", "")
                salary_l = re.findall("\d+\.?\d+", salary_text)

                if len(salary_l) == 2:
                    salary = (float(salary_l[0]) + float(salary_l[1])) / 2
                    salary = round(salary, 2)
                else:
                    salary = float(salary_l[0])

                # Compute monthly salary, use average for intervals
                # Assume every shift is 8hrs long and each week consists of 5 work days
                if "an hour" in salary_text or "per hour" in salary_text:
                    salary *= 8 * 5 * 4

                if "a year" in salary_text or "per year" in salary_text:
                    salary /= 12

                salary = round(salary, 2)

            # Get job type if available
            elif detail.contents[0].get_text() == "Job type":
                job_type = detail.contents[1].get_text()

        # Get the job description text and remove unnecessary whitespace and newlines
        job_descr = job_view_soup.find("div", attrs={"id": "jobDescriptionText"}).get_text()
        job_descr = job_descr.strip()
        job_descr = re.sub("\n+", " ", job_descr)
        job_descr = re.sub(" +", " ", job_descr)

        # Close new tab and switch back to tab with jobs list
        driver.close()
        driver.switch_to.window(driver.window_handles[0])

        df.loc[len(df.index)] = [title, job_type, company, location, remote, salary, job_descr]
            
    # Close popover if appearing on page, Note that we are using find_elements (emphasis on the "s")
    close_btn_popover = driver.find_elements(By.CSS_SELECTOR, "button.popover-x-button-close")
    
    if len(close_btn_popover) > 0:
        close_btn_popover[0].click()
    
    # Get next search result page
    nextpage = find_next(soup, driver)
    
    if nextpage:
        nextpage.click()
    else:
        break
    
# Quit browser and close csv file
driver.quit()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\Owner\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\Owner\AppData\Local\Temp\ipykernel_15056\3644775193.py:32: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)

# %% [markdown]
# #### Step 7: Store collected data in a csv file

# %%
from os import remove
from os.path import exists

# Remove any existing file called "indeed_da_jobs.csv"
if exists("indeed_da_jobs.csv"):
    remove("indeed_da_jobs.csv")
    
# Store scraped data in csv file
df.to_csv("indeed_da_jobs.csv")
    
# Test-read the csv file
test = pd.read_csv("indeed_da_jobs.csv", index_col=[0])
test.head(5)
# Out:
#                          Job_Title   Job_Type                Company  \
# 0            Data Security Analyst  Full-time    CWB Financial Group
# 1                Inventory Analyst  Full-time       Canadian Natural
# 2    Junior Financial Data Analyst  Full-time     Lawson Lundell LLP
# 3  Contract Data Reporting Analyst  Temporary            Robert Half
# 4           Financial Data Analyst  Full-time  Government of Alberta
#
#         Location  Remote  Salary  \
# 0  Hybrid Canada    True     NaN
# 1    Calgary, AB   False     NaN
# 2    Calgary, AB   False     NaN
# 3   Edmonton, AB    True     NaN
# 4   Edmonton, AB    True  6190.0
#
#                                              Summary
# 0  At CWB , we strive to build value for the peop...
# 1  Inventory Analyst- (2210923)The Opportunity:Ar...
# 2  Lawson Lundell LLP is a leading regional Canad...
# 3  Robert Half is recruiting now for an experienc...
# 4  Job Information Job Requisition ID: 29202 Mini...

# %% [markdown]
# ___
# ### Bonus
#
# #### Step 1: Get the summary of each scraped job

# %%
job_summaries = test.loc[:, ['Summary']]
job_summaries
# Out:
#                                                Summary
# 0    At CWB , we strive to build value for the peop...
# 1    Inventory Analyst- (2210923)The Opportunity:Ar...
# 2    Lawson Lundell LLP is a leading regional Canad...
# 3    Robert Half is recruiting now for an experienc...
# 4    Job Information Job Requisition ID: 29202 Mini...
# ..                                                 ...
# 145  Overview: KPMG is an industry leading firm tha...
# 146  About Athennian Athennian increases trust in b...
# 147  Resolute is a Full-Service IT firm with a mult...
# 148  12-month contract Let’s impact lives for the b...
# 149  Experience Required: 5+ Years Essential Skills...
#
# [150 rows x 1 columns]

# %% [markdown]
# #### Step 2: Download English stop words & add more stop words if needed
#
# "[Stop words](https://en.wikipedia.org/wiki/Stop_word) are any word in a stop list which are filtered out before or after processing of natural language data." - Wikipedia

# %%
import nltk
from nltk.corpus import stopwords

nltk.download("stopwords")
stop_words = stopwords.words("English")
stop_words.extend(["skills", "data", "ability", "information", "business", "analyst", 
                   "requirements", "strong", "analysis", "process", "working"])
stop_words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     D:\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'skills',
#  'data',
#  'ability',
#  'information',
#  'business',
#  'analyst',
#  'requirements',
#  'strong',
#  'analysis',
#  'process',
#  'working']

# %% [markdown]
# #### Step 3: Filter out stop words from job summaries

# %%
summary_words_list = []
for row in job_summaries.itertuples():
    summary = re.findall("[\w']+", row[1])
    summary = filter(lambda x: x.lower() not in stop_words, summary)   # Not a stop word
    summary = map(str.capitalize, summary)
    
    summary_words_list.extend(summary)
    
print(summary_words_list)
# Out:
# ['Cwb', 'Strive', 'Build', 'Value', 'People', 'Choose', 'Us', 'Every', 'Day', 'People', 'Clients', 'Investors', 'Holding', 'True', 'Values', 'Guide', 'Us', 'Put', 'People', 'First', 'Build', 'Relationships', 'Intention', 'Seek', 'Embrace', 'New', 'Ideas', 'Knowing', 'Better', 'Always', 'Possible', 'Believe', 'Things', 'Important', 'Harness', 'Power', 'Inclusion', 'Culture', 'Show', 'Individuals', 'Team', 'Accomplish', 'Strategy', 'Canadian', 'Western', 'Bank', 'Cwb', 'Full', 'Service', 'Bank', 'Canada', 'Strategic', 'Focus', 'Meet', 'Unique', 'Financial', 'Needs', 'Businesses', 'Owners', 'Teams', 'Take', 'Relationship', 'Based', 'Approach', 'Deliver', 'Uniquely', 'Proactive', 'Client', 'Experience', 'Highly', 'Personalized', 'Service', 'Specialized', 'Expertise', 'Customized', 'Solutions', 'Faster', 'Response', 'Times', 'Provide', 'Full', 'Service', 'Personal', 'Banking', 'Nation', 'Wide', 'Specialized', 'Financing', 'Targeted', 'Industries', 'Comprehensive', 'Wealth', 'Management', 'Offerings', 'Trust', 'Services', 'Together', 'United', 'One', 'Cwb', 'Firmly', 'Committed', 'Responsible', 'Creation', 'Value', 'Stakeholders', 'Approach', 'Sustainability', 'Support', 'Continued', 'Success', 'Highly', 'Engaged', 'Teams', 'Operate', 'Within', 'Client', 'Centric', 'Collaborative', 'Change', 'Ready', 'Culture', 'Core', 'Focus', 'Achieve', 'Vision', 'Become', 'Best', 'Full', 'Service', 'Bank', 'Owners', 'Canada', 'Continue', 'Transform', 'Capabilities', 'Building', 'Momentum', 'Cwb', 'Offers', 'Unmatched', 'Employee', 'Experience', 'Guaranteed', 'Redefine', 'Means', 'Work', 'Top', 'Employer', 'Culture', 'Key', 'Differentiator', 'One', 'Proud', 'Opportunity', 'Cwb', 'Important', 'Asset', 'Taking', 'Consideration', 'Rise', 'Global', 'Cyber', 'Security', 'Incidents', 'Direct', 'Impact', 'Branding', 'Reputation', 'Cwb', 'Financial', 'Group', 'Committed', 'Developing', 'Implementing', 'Policies', 'Processes', 'Technologies', 'Manage', 'Security', 'Proactively', 'Effectively', 'Clients', 'Employees', 'Security', 'Member', 'Protection', 'Team', 'Within', 'Cwb', 'Security', 'Office', 'Iso', 'Responsible', 'Implementation', 'Day', 'Day', 'Operations', 'Modern', 'Day', 'Industry', 'Leading', 'Security', 'Loss', 'Prevention', 'Technologies', 'Specific', 'Accountabilities', 'Accountability', '1', 'Protection', 'Apply', 'Risk', 'Management', 'Treatment', 'Methodologies', 'Balance', 'Needs', 'Cwb', 'Financial', 'Group', 'Ensuring', 'Usage', 'Behaviours', 'Changed', 'Mitigate', 'Identified', 'Risks', 'Assist', 'Managing', 'Day', 'Day', 'Activities', 'Protection', 'Team', 'Relate', 'Ongoing', 'Discovery', 'Cloud', 'Access', 'Security', 'Rights', 'Management', 'Enterprise', 'Storage', 'Strategies', 'Maintain', 'Solutions', 'Secure', 'Control', 'Email', 'Documents', 'Sensitive', 'Applying', 'Principal', 'Least', 'Privilege', 'Support', 'Units', 'Ensuring', 'Security', 'Alignment', 'Identify', 'Opportunities', 'Perspectives', 'People', 'Processes', 'Technology', 'Ensuring', 'Highest', 'Quality', 'Confidentiality', 'Integrity', 'Availability', 'Assets', 'Participate', 'Educating', 'Company', 'Employees', 'Protection', 'Privacy', 'Best', 'Practices', 'Execute', 'Procedures', 'Perform', 'Detailed', 'Root', 'Cause', 'Document', 'Results', 'Suggest', 'Improvements', 'Operational', 'Efficiencies', 'Identify', 'Opportunities', 'Reduce', 'Risk', 'Document', 'Remediation', 'Options', 'Regarding', 'Acceptance', 'Mitigation', 'Risk', 'Scenarios', 'Relevant', 'Protection', 'Contribute', 'Incident', 'Response', 'Ir', 'Plans', 'Playbooks', 'Needed', 'Accountability', '2', 'Loss', 'Prevention', 'Assist', 'Improving', 'Building', 'Operational', 'Procedures', 'Leverage', 'Cloud', 'Based', 'Technologies', 'Purpose', 'Ongoing', 'Monitoring', 'Continuous', 'Protection', 'Usage', 'Sharing', 'Recommend', 'Facilitate', 'Implementation', 'Technical', 'Controls', 'Support', 'Enforce', 'Defined', 'Security', 'Policies', 'Assist', 'Security', 'Incidents', 'Investigations', 'Work ...

# %% [markdown]
# #### Step 4: Count the number of times each word appears overall in the summaries

# %%
from collections import Counter

summary_counter = Counter(summary_words_list)
summary_counter
# Out:
# Counter({'Cwb': 24,
#          'Strive': 18,
#          'Build': 91,
#          'Value': 83,
#          'People': 132,
#          'Choose': 6,
#          'Us': 110,
#          'Every': 49,
#          'Day': 64,
#          'Clients': 119,
#          'Investors': 7,
#          'Holding': 2,
#          'True': 13,
#          'Values': 44,
#          'Guide': 8,
#          'Put': 10,
#          'First': 32,
#          'Relationships': 53,
#          'Intention': 2,
#          'Seek': 13,
#          'Embrace': 10,
#          'New': 136,
#          'Ideas': 37,
#          'Knowing': 3,
#          'Better': 44,
#          'Always': 28,
#          'Possible': 13,
#          'Believe': 27,
#          'Things': 14,
#          'Important': 22,
#          'Harness': 2,
#          'Power': 109,
#          'Inclusion': 44,
#          'Culture': 63,
#          'Show': 10,
#          'Individuals': 45,
#          'Team': 416,
#          'Accomplish': 9,
#          'Strategy': 40,
#          'Canadian': 38,
#          'Western': 21,
#          'Bank': 11,
#          'Full': 90,
#          'Service': 134,
#          'Canada': 117,
#          'Strategic': 53,
#          'Focus': 51,
#          'Meet': 72,
#          'Unique': 31,
#          'Financial': 81,
#          'Needs': 106,
#          'Businesses': 15,
#          'Owners': 15,
#          'Teams': 95,
#          'Take': 51,
#          'Relationship': 13,
#          'Based': 90,
#          'Approach': 22,
#          'Deliver': 52,
#          'Uniquely': 3,
#          'Proactive': 9,
#          'Client': 106,
#          'Experience': 599,
#          'Highly': 58,
#          'Personalized': 3,
#          'Specialized': 6,
#          'Expertise': 36,
#          'Customized': 6,
#          'Solutions': 176,
#          'Faster': 6,
#          'Response': 6,
#          'Times': 13,
#          'Provide': 168,
#          'Personal': 54,
#          'Banking': 9,
#          'Nation': 2,
#          'Wide': 26,
#          'Financing': 3,
#          'Targeted': 4,
#          'Industries': 10,
#          'Comprehensive': 28,
#          'Wealth': 3,
#          'Management': 357,
#          'Offerings': 7,
#          'Trust': 13,
#          'Services': 114,
#          'Together': 32,
#          'United': 6,
#          'One': 94,
#          'Firmly': 1,
#          'Committed': 75,
#          'Responsible': 94,
#          'Creation': 15,
#          'Stakeholders': 127,
#          'Sustainability': 8,
#          'Support': 269,
#          'Continued': 6,
#          'Success': 60,
#          'Engaged': 6,
#          'Operate': 13,
#          'Within': 104,
#          'Centric': 5,
#          'Collaborative': 37,
#          'Change': 68,
#          'Ready': 22,
#          'Core': 39,
#          'Achieve': 35,
#          'Vision': 38,
#          'Become': 17,
#          'Best': 100,
#          'Continue': 11,
#          'Transform': 15,
#          'Capabilities': 35,
#          'Building': 65,
#          'Momentum': 1,
#          'Offers': 24,
#          'Unmatched': 2,
#          'Employee': 62,
#          'Guaranteed': 1,
#          'Redefine': 4,
#          'Means': 14,
#          'Work': 594,
#          'Top': 48,
#          'Employer': 75,
#          'Key': 88,
#          'Differentiator': 1,
#          'Proud': 21,
#          'Opportunity': 127,
#          'Asset': 143,
#          'Taking': 14,
#          'Consideration': 15,
#          'Rise': 1,
#          'Global': 55,
#          'Cyber': 4,
#          'Security': 53,
#          'Incidents': 9,
#          'Direct': 19,
#          'Impact': 52,
#          'Branding': 2,
#          'Reputation': 13,
#          'Group': 64,
#          'Developing': 65,
#          'Implementing': 19,
#          'Policies': 44,
#          'Processes': 144,
#          'Technologies': 43,
#          'Manage': 75,
#          'Proactively': 10,
#          'Effectively': 53,
#          'Employees': 106,
#          'Member': 24,
#          'Protection': 19,
#          'Office': 98,
#          'Iso': 7,
#          'Implementation': 51,
#          'Operations': 103,
#          'Modern': 2,
#          'Industry': 107,
#          'Leading': 46,
#          'Loss': 5,
#          'Prevention': 3,
#          'Specific': 41,
#          'Accountabilities': 8,
#          'Accountability': 17,
#          '1': 52,
#          'Apply': 117,
#          'Risk': 40,
#          'Treatment': 2,
#          'Methodologies': 24,
#          'Balance': 20,
#          'Ensuring': 30,
#          'Usage': 8,
#          'Behaviours': 1,
#          'Changed': 2,
#          'Mitigate': 5,
#          'Identified': 8,
#          'Risks': 22,
#          'Assist': 70,
#          'Managing': 35,
#          'Activities': 60,
#          'Relate': 8,
#          'Ongoing': 30,
#          'Discovery': 7,
#          'Cloud': 15,
#          'Access': 45,
#          'Rights': 10,
#          'Enterprise': 37,
#          'Storage': 6,
#          'Strategies': 60,
#          'Maintain': 82,
#          'Secure': 5,
#          'Control': 10,
#          'Email': 19,
#          'Documents': 19,
#          'Sensitive': 16,
#          'Applying': 31,
#          'Principal': 2,
#          'Least': 11,
#          'Privilege': 1,
#          'Units': 17,
#          'Alignment': 7,
#          'Identify': 84,
#          'Opportunities': 120,
#          'Perspectives': 20,
#          'Technology': 141,
#          'Highest': 11,
#          'Quality': 138,
#          'Confidentiality': 4,
#          'Integrity': 53,
#          'Availability': 4,
#          'Assets': 18,
#          'Participate': 40,
#          'Educating': 1,
#          'Company': 117,
#          'Privacy': 23,
#          'Practices': 59,
#          'Execute': 22,
#          'Procedures': 46,
#          'Perform': 67,
#          'Detailed': 10,
#          'Root': 10,
#          'Cause': 4,
#          'Document': 42,
#          'Results': 72,
#          'Suggest': 3,
#          'Improvements': 34,
#          'Operational': 75,
#          'Efficiencies': 14,
#          'Reduce': 6,
#          'Remediation': 4,
#          'Options': 21,
#          'Regarding': 18,
#          'Acceptance': 15,
#          'Mitigation': 1,
#          'Scenarios': 5,
#          'Relevant': 48,
#          'Contribute': 39,
#          'Incident': 10,
#          'Ir': 1,
#          'Plans': 43,
#          'Playbooks': 2,
#          'Needed': 20,
#          '2': 46,
#          'Improving': 25,
#          'Leverage': 14,
#          'Purpose': 27,
#          'Monitoring': 24,
#          'Continuous': 33,
#          'Sharing': 19,
#          'Recommend': 10,
#          'Facilitate': 27,
#          'Technical': 186,
#          'Controls': 13,
#          'Enforce': 2,
#          'Defined': 10,
#          'Investigations': 1,
#          'Closely': 39,
#          'Identity': 24,
#          'Ensure': 97,
#          'Provisioned': 1,
#          'Centralized': 3,
#          'Identities': 5,
#          'Need': 57,
#          'Know': 25,
#          'Basis': 22,
#          'Retention': 7,
#          'Schedules': 4,
#          'Classification': 19,
#          'Use': 99,
#          'Automatically': 1,
#          'Label': 1,
#          'Competencies': 30,
#          'Education': 107,
#          'Post': 55,
#          'Secondary': 57,
#          'Diploma': 41,
#          'Field': 59,
#          'Computing': 2,
#          'Science': 71,
#          'Systems': 177,
#          'Equivalent': 39,
#          'Required': 183,
#          'Comptia': 1,
#          'Isc': 1,
#          'Entry': 10,
#          'Level': 61,
#          'Cybersecurity': 2,
#          'Certification': 33,
#          'System': 108,
#          'Certified': 9,
#          'Practitioner': 1,
#          'Sscp': 1,
#          'Commitment': 35,
#          'Obtain': 9,
#          'Two': 20,
#          'Years': 152,
#          'Employment': 76,
#          'Professional': 71,
#          'Minimum': 56,
#          '5': 57,
#          'Domain': 3,
#          'Administering': 1,
#          'Governance': 58,
#          'Regulatory': 8,
#          'Pii': 1,
#          'Assessment': 27,
#          'Actively': 16,
#          'Define': 28,
#          'Inventory': 48,
#          'Flows': 10,
#          'Lineage': 2,
#          'Infrastructure': 30,
#          'Mapping': 21,
#          'Stewardship': 7,
#          'Previous': 22,
#          'Microsoft': 59,
#          '365': 6,
#          'Purview': 2,
#          'Aka': 1,
#          'Compliance': 21,
#          'Would': 58,
#          'Beneficial': 10,
#          'End': 66,
#          'Lifecycle': 20,
#          'Solid': 18,
#          'Understanding': 106,
#          'Encryption': 4,
#          'Anonymization': 1,
#          'Masking': 1,
#          'Methods': 24,
#          'Hashing': 1,
#          'Tokenization': 1,
#          'Dke': 1,
#          'Pgp': 1,
#          'Pki': 1,
#          'Ckm': 1,
#          'Byok': 1,
#          'Etc': 54,
#          'Prior': 14,
#          'Bigid': 1,
#          'Onetrust': 1,
#          'Similar': 25,
#          'Products': 55,
#          'Discovering': 5,
#          'Protecting': 1,
#          'Structured': 10,
#          'Applicable': 12,
#          'E': 41,
#          'File': 2,
#          'Scripting': 8,
#          'Automation': 17,
#          'Knowledge': 212,
#          'Public': 37,
#          'Network': 18,
#          'Databases': 34,
#          'Familiarity': 16,
#          'Frameworks': 8,
#          'Standards': 45,
#          'Including': 181,
#          'Osfi': 1,
#          'B': 14,
#          '13': 6,
#          'Nist': 2,
#          'Framework': 19,
#          '27000': 1,
#          'Series': 1,
#          'Sp': 1,
#          '800': 1,
#          '53': 1,
#          'Organizations': 18,
#          'Rev': 1,
#          '4': 37,
#          'Windows': 6,
#          'Linux': 4,
#          'Auditing': 1,
#          'Demonstrated': 62,
#          'Projects': 104,
#          'Moderate': 5,
#          'High': 104,
#          'Complexity': 9,
#          'Library': 7,
#          'Itil': 4,
#          'Desirable': 15,
#          'Defining': 7,
#          'Metrics': 27,
#          'Kpis': 7,
#          'Dashboards': 51,
#          'Exceptional': 26,
#          'Written': 69,
#          'Verbal': 49,
#          'Listening': 3,
#          'Interpersonal': 42,
#          'Critical': 19,
#          'Judgement': 11,
#          'Make': 78,
#          'Decisions': 46,
#          'Solve': 28,
#          'Problems': 83,
#          'Involving': 7,
#          'Various': 75,
#          'Levels': 36,
#          'Ambiguity': 5,
#          'Good': 29,
#          'Analytical': 119,
#          'Attention': 40,
#          'Detail': 60,
#          'Firm': 23,
#          'Staying': 5,
#          'Informed': 11,
#          'Abreast': 5,
#          'Emerging': 9,
#          'Issues': 98,
#          'Trends': 49,
#          'Sound': 13,
#          'Advanced': 76,
#          'Serve': 31,
#          'Subject': 22,
#          'Matter': 18,
#          'Expert': 28,
#          'Cross': 41,
#          'Functional': 54,
#          'Initiatives': 58,
#          'Environment': 202,
#          'Independently': 37,
#          'Autonomously': 4,
#          'Communicate': 48,
#          'User': 62,
#          'Friendly': 11,
#          'Language': 30,
#          'Generate': 9,
#          'Reports': 133,
#          'Leadership': 41,
#          'Lines': 8,
#          'Go': 13,
#          'Today': 29,
#          'Winners': 2,
#          'Admired': 2,
#          'Corporate': 56,
#          '2021': 8,
#          'Recognized': 25,
#          '50': 11,
#          'Workplaces': 6,
#          'Great': 60,
#          'Places': 7,
#          '2022': 47,
#          'Mental': 12,
#          'Wellness': 35,
#          'Driven': 45,
#          'Benefits': 108,
#          'Matters': 9,
#          'Offer': 51,
#          'Award': 5,
#          'Winning': 6,
#          'Package': 31,
#          'Includes': 18,
#          'Hybrid': 21,
#          'Environments': 23,
#          'Everyday': 9,
#          'Flexibility': 18,
#          '100': 22,
#          'Funded': 4,
#          'Health': 118,
#          'Coverage': 13,
#          'Care': 88,
#          'Spending': 17,
#          'Account': 24,
#          'Flexible': 48,
#          'Program': 91,
#          'Generous': 12,
#          'Time': 173,
#          'Away': 4,
#          'Unplug': 2,
#          'Rest': 3,
#          'Recover': 2,
#          'Bring': 37,
#          'Whole': 11,
#          'Self': 53,
#          'Journey': 9,
#          'Requiring': 9,
#          'Practice': 18,
#          'Result': 6,
#          'Powerful': 4,
#          'Outcome': 4,
#          'Perspective': 10,
#          'Voice': 7,
#          'Heard': 7,
#          'Find': 25,
#          'Community': 58,
#          'Family': 31,
#          'Represented': 2,
#          'Groups': 43,
#          'Career': 74,
#          'Development': 205,
#          'Invest': 7,
#          'Help': 79,
#          'Reach': 19,
#          'Goals': 41,
#          'Organization': 87,
#          'Coaching': 10,
#          'Design': 139,
#          'Investment': 34,
#          'Innovation': 33,
#          'Learn': 67,
#          'Grow': 38,
#          'Enhance': 18,
#          'Play': 14,
#          'Win': 2,
#          'Fail': 4,
#          'Forward': 17,
#          'Recognition': 5,
#          'Peer': 6,
#          'Programs': 59,
#          'Moment': 4,
#          'Monumental': 2,
#          'Wins': 4,
#          'Giving': 6,
#          'Difference': 20,
#          'Drive': 49,
#          'Economic': 24,
#          'Prosperity': 3,
#          'Get': 38,
#          'Involved': 12,
#          'Volunteer': 10,
#          'Fundraise': 2,
#          'Esg': 4,
#          'Focused': 33,
#          'Spend': 4,
#          'Rewards': 9,
#          'Base': 6,
#          'Salary': 38,
#          'Pay': 27,
#          'Performance': 70,
#          'Incentives': 2,
#          'Retirement': 3,
#          'Forever': 2,
#          'Got': 12,
#          'Covered': 2,
#          'Ownership': 16,
#          'Greater': 8,
#          'Sense': 9,
#          'Motivation': 3,
#          'Empowerment': 6,
#          'Owner': 5,
#          'F': 3,
#          'Ind': 2,
#          'Cwbcareers': 2,
#          'Com': 35,
#          'Li': 11,
#          'Eh1': 1,
#          'Equitable': 22,
#          'Providing': 59,
#          'Safe': 22,
#          'Inclusive': 55,
#          'Diverse': 75,
#          'Workforce': 24,
#          'Thrives': 7,
#          'Welcomed': 5,
#          'Encouraged': 10,
#          'Dignity': 5,
#          'Respect': 16,
#          'Equality': 3,
#          'Non': 41,
#          'Negotiables': 2,
#          'Require': 44,
#          'Accommodation': 37,
#          'Part': 74,
#          'Recruitment': 35,
#          'Selection': 21,
#          'Please': 104,
#          'Closing': 27,
#          'Date': 41,
#          'Position': 159,
#          'Closes': 3,
#          '12': 15,
#          '01am': 2,
#          'Close': 6,
#          '06': 7,
#          '22': 4,
#          '2210923': 1,
#          'Someone': 17,
#          'Passion': 30,
#          'Analyzing': 51,
#          'Investigating': 5,
#          'Organizing': 4,
#          'Master': 51,
#          'Might': 5,
#          'Looking': 89,
#          'Act': 30,
#          'Partner': 26,
#          'Supply': 38,
#          'Variety': 54,
#          'Additional': 25,
#          'Persistent': 2,
#          'Problem': 97,
#          'Solver': 8,
#          'Enjoys': 1,
#          'Intensive': 1,
#          'Deeply': 2,
#          'Accuracy': 25,
#          'Using': 119,
#          'Clear': 20,
#          'Open': 44,
#          'Communication': 133,
#          'Utilizing': 14,
#          'Current': 32,
#          'Chain': 23,
#          'Digital': 59,
#          'Valuable': 16,
#          'Natural': 23,
#          'Maintenance': 31,
#          'Improvement': 64,
#          'Attributes': 3,
#          'Improve': 55,
#          'Transactional': 7,
#          'Efficiency': 20,
#          'Reporting': 179,
#          'Analytics': 132,
#          'Procurement': 10,
#          'Measures': 13,
#          'Present': 24,
#          'Insights': 63,
#          'Concise': 13,
#          'Manner': 21,
#          'Visualization': 52,
#          'Tools': 138,
#          'Descriptive': 1,
#          'Happened': 1,
#          'Diagnostic': 2,
#          'Happen': 5,
#          'Develop': 181,
#          'Actionable': 14,
#          'Recommendations': 39,
#          'Evaluating': 3,
#          'Workflows': 5,
#          'Conducting': 25,
#          'Directly': 24,
#          'Outcomes': 14,
#          'Details': 11,
#          'Job': 158,
#          'Location': 52,
#          'Calgary': 70,
#          'Alberta': 108,
#          'Eligible': 13,
#          'Relocation': 8,
#          'Pursuant': 3,
#          'Regular': 28,
#          'Policy': 62,
#          'May': 77,
#          'Travel': 24,
#          'Site': 22,
#          'Interact': 9,
#          'Collaborate': 41,
#          'Streams': 1,
#          'Safety': 29,
#          'Competitive': 51,
#          'Stock': 10,
#          'Savings': 8,
#          'Plan': 53,
#          'Qualifications': 104,
#          'Procure': 1,
#          'P2p': 1,
#          'Undergraduate': 7,
#          'Degree': 121,
#          'Either': 8,
#          'Mathematics': 14,
#          'Statistics': 24,
#          'Economics': 26,
#          'Computer': 69,
#          'Sciences': 13,
#          'Related': 152,
#          'Discipline': 21,
#          'Spreadsheet': 5,
#          'Software': 122,
#          'Google': 8,
#          'Sheets': 2,
#          'Ms': 47,
#          'Excel': 87,
#          'Powerpoint': 21,
#          'Erp': 28,
#          'Maximo': 4,
#          'Sap': 17,
#          'Oracle': 34,
#          'Jd': 2,
#          'Edwards': 2,
#          'Analyze': 87,
#          'Create': 72,
#          'Tableau': 27,
#          'Tibco': 1,
#          'Spotfire': 1,
#          'Bi': 99,
#          'Consulting': 21,
#          'Internally': 6,
#          'Function': 12,
#          'Desired': 5,
#          'Senior': 49,
#          'Independent': 12,
#          'Crude': 32,
#          'Oil': 28,
#          'Gas': 30,
#          'Exploration': 4,
#          'Production': 14,
#          'Diversified': 7,
#          'Comprised': 2,
#          'Balanced': 2,
#          'Portfolio': 22,
#          'Light': 3,
#          'Synthetic': 1,
#          'Heavy': 3,
#          'Operates': 7,
#          'Kingdom': 1,
#          'Offshore': 3,
#          'Africa': 1,
#          'Live': 14,
#          'Mission': 23,
#          'Statement': 8,
#          "Company's": 1,
#          'Shareholders': 3,
#          'Right': 26,
#          'Fun': 17,
#          'Long': 20,
#          'Term': 24,
#          'Presence': 3,
#          'Communities': 40,
#          'Revenues': 1,
#          'Governments': 2,
#          'Goods': 2,
#          'Essential': 40,
#          'Resources': 34,
#          'Training': 70,
#          'Last': 5,
#          '30': 12,
#          'Grown': 4,
#          'Nine': 1,
#          '10': 18,
#          '000': 30,
#          'Increased': 3,
#          'Approximately': 4,
#          '400': 2,
#          'Boe': 2,
#          '1989': 1,
#          'Million': 7,
#          'Conduct': 49,
#          'Way': 28,
#          'Identifies': 5,
#          'Minimizes': 1,
#          'Mitigates': 1,
#          'Harm': 1,
#          'Contractors': 6,
#          'Limited': 17,
#          'Cnrl': 1,
#          'Publicly': 2,
#          'Traded': 2,
#          'Tsx': 1,
#          'Nyse': 1,
#          'Cnqapplication': 1,
#          'Deadline': 11,
#          'June': 13,
#          '19': 44,
#          'Primary': 31,
#          'Calgaryjob': 1,
#          'Type': 34,
#          'Lawson': 5,
#          'Lundell': 4,
#          'Llp': 4,
#          'Regional': 7,
#          'Law': 19,
#          'Offices': 6,
#          'Vancouver': 11,
#          'Kelowna': 1,
#          'Yellowknife': 1,
#          'Respected': 12,
#          'Peers': 3,
#          'Legal': 16,
#          'Publications': 4,
#          'Recently': 3,
#          'Named': 4,
#          'Bc': 4,
#          'Employers': 13,
#          'Also': 42,
#          'Fastest': 4,
#          'Growing': 30,
#          'Seeking': 23,
#          'Recent': 7,
#          'University': 74,
#          'Graduate': 6,
#          'Role': 166,
#          'Join': 76,
#          'Paralegal': 1,
#          'Project': 135,
#          'Completions': 1,
#          'Performing': 20,
#          'Real': 41,
#          'Estate': 30,
#          'Numerous': 4,
#          'Land': 2,
#          'Closings': 1,
#          'Thousands': 1,
#          'Individual': 36,
#          'Hours': 42,
#          'Monday': 17,
#          'Friday': 18,
#          '8': 24,
#          '30am': 1,
#          '30pm': 1,
#          'Remote': 34,
#          'Option': 5,
#          'Preference': 14,
#          'Given': 13,
#          'Candidates': 71,
#          'Standard': 24,
#          'Responsibilities': 79,
#          'Tracking': 11,
#          'Flow': 7,
#          'Funds': 2,
#          'Review': 43,
#          'Completion': 12,
#          'Federal': 6,
#          'Tax': 6,
#          'Filings': 3,
#          'Revenue': 5,
#          'Agency': 11,
#          'Year': 55,
#          'Bachelor': 27,
#          'Accredited': 6,
#          'Institution': 25,
#          'Proven': 35,
#          'Handle': 11,
#          'Multiple': 67,
#          'Tasks': 55,
#          'Concurrent': 4,
#          'Competing': 9,
#          'Priorities': 30,
#          'Remaining': 4,
#          'Calm': 2,
#          'Volume': 8,
#          'Fast': 47,
#          'Paced': 44,
#          'Internet': 2,
#          'Research': 145,
#          'Msoffice': 2,
#          'Suite': 25,
#          'Word': 14,
#          'Follow': 18,
#          'Instructions': 2,
#          'Comfortable': 20,
#          'Excellent': 93,
#          'Polite': 1,
#          'Positive': 35,
#          'Oral': 11,
#          'Player': 27,
#          'Motivated': 28,
#          'Hardworking': 3,
#          'Outlook': 10,
#          'Like': 63,
#          'Share': 26,
#          'Submit': 22,
#          'Resume': 17,
#          'Cover': 15,
#          'Letter': 14,
#          'Aubrey': 1,
#          'Guild': 1,
#          'Young': 9,
#          'Exciting': 25,
#          'Perks': 8,
#          'Compensation': 49,
#          'Extended': 18,
#          'Dental': 27,
#          'Country': 8,
#          'Life': 55,
#          'Ad': 25,
#          'Fitness': 5,
#          'Benefit': 18,
#          'Reimbursement': 7,
#          'Equipment': 9,
#          'Membership': 5,
#          'Paid': 40,
#          'Vacation': 18,
#          'Starts': 8,
#          '3': 71,
#          'Weeks': 14,
#          'Days': 21,
#          'Sick': 4,
#          'Contribution': 6,
#          'Pension': 14,
#          'Matched': 4,
#          'Rrsp': 13,
#          'Tfsa': 1,
#          'Bonuses': 4,
#          'Referral': 9,
#          'Bonus': 21,
#          'Annual': 19,
#          'Party': 15,
#          'Happy': 7,
#          'Staff': 50,
#          'Appreciation': 3,
#          'Week': 26,
#          'Many': 13,
#          'Social': 42,
#          'Events': 16,
#          'Awards': 2,
#          'Extra': 1,
#          'Expect': 7,
#          'Diversity': 65,
#          'Inclusiveness': 2,
#          'Fostering': 5,
#          'Workplace': 39,
#          'Constant': 2,
#          'Learning': 51,
#          'Next': 28,
#          'Discrimination': 7,
#          'Free': 16,
#          'Harassment': 1,
#          'Although': 1,
#          'Thank': 34,
#          'Applicants': 84,
#          'Interest': 40,
#          'Shortlisted': 3,
#          'Contacted': 42,
#          'Phone': 8,
#          'Calls': 3,
#          'Types': 17,
#          'Permanent': 31,
#          'Overtime': 11,
#          'Disability': 33,
#          'Insurance': 54,
#          'Discounted': 1,
#          'Food': 21,
#          'Schedule': 35,
#          'Hour': 18,
#          'Shift': 21,
#          'Weekends': 1,
#          'Robert': 12,
#          'Half': 12,
#          'Recruiting': 9,
#          'Experienced': 20,
#          'Fulfill': 2,
#          'Contract': 20,
#          'Temporary': 16,
#          'Edmonton': 58,
#          'Successful': 59,
#          'Candidate': 61,
#          'Accountable': 8,
#          'Evolving': 9,
#          'Utilize': 9,
#          'Sql': 111,
#          'Queries': 29,
#          'Query': 26,
#          'Gathering': 27,
#          'Aspects': 15,
#          'Ab': 38,
#          'Home': 29,
#          'Concessions': 2,
#          'Wage': 2,
#          'Along': 11,
#          'Online': 40,
#          'Must': 61,
#          'Haves': 7,
#          'Custom': 9,
#          'Proficient': 19,
#          'Manipulation': 8,
#          'Visual': 25,
#          'Basic': 9,
#          'Depth': 21,
#          'Report': 39,
#          'Generation': 11,
#          'Database': 48,
#          'Source': 9,
#          'Shape': 5,
#          'Cycle': 24,
#          'Patterns': 15,
#          'Organizational': 45,
#          'Oriented': 32,
#          'Thorough': 7,
#          'Enquiring': 1,
#          'Mind': 3,
#          'Think': 19,
#          'Outside': 10,
#          'Box': 6,
#          'Search': 4,
#          'Answers': 4,
#          'Planning': 54,
#          'Communicant': 1,
#          'Adept': 4,
#          'Maintaining': 31,
#          'Collaborating': 13,
#          'Remain': 9,
#          'Suitable': 11,
#          'Selected': 43,
#          'Quote': 1,
#          'Reference': 10,
#          '05110': 2,
#          '0012322697': 1,
#          'Communications': 28,
#          'World': 42,
#          'Largest': 15,
#          'Talent': 19,
#          'Connects': 3,
#          'Qualified': 33,
#          'Seekers': 6,
#          'Companies': 35,
#          ...})

# %% [markdown]
# #### Step 5: Obtain the 10 most common words overall in the job descriptions

# %%
summary_counter.most_common(10)
# Out:
# [('Experience', 599),
#  ('Work', 594),
#  ('Team', 416),
#  ('Management', 357),
#  ('Support', 269),
#  ('Knowledge', 212),
#  ('Development', 205),
#  ('Environment', 202),
#  ('Technical', 186),
#  ('Required', 183)]

# %% [markdown]
# It seems that the "Experience" and "Team" elements are recurring in most Data Analyst job descriptions in Alberta.

# %% [markdown]
# #### Step 6: Find the count the per job count for some specific words

# %%
job_count = len(df.index)
count_per_job = {k: round(v/ job_count, 3) for k, v in summary_counter.items()}
print("Python", count_per_job["Python"])
print("Excel", count_per_job["Excel"])
print("SQL", count_per_job["Sql"])
print("Tableau", count_per_job["Tableau"])
print("Power BI", count_per_job["Bi"])
print("Remote", count_per_job["Remote"])
# Out:
# Python 0.167
# Excel 0.58
# SQL 0.74
# Tableau 0.18
# Power BI 0.66
# Remote 0.227

# %% [markdown]
# SQL and Power BI seem to be very common in job descriptions. Assuming each word are present in roughly equal amount in every job description, almost 75% of Data Analyst jobs in Alberta require SQL and about 66% require Power BI.
